# %%
f = exp(x)

# %%
plot([f,[taylor(f, x, 0, y) for y in [2..5]]], (x, 0, 5), scale='semilogy', aspect_ratio='automatic')
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
g = ln(1+x)

# %%
plot([g,[taylor(g, x, 0, y) for y in [2..5]]], (x, 0, 5), aspect_ratio='automatic', scale='linear')
# Out:
# Graphics object consisting of 5 graphics primitives
